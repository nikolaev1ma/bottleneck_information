# %%
import matplotlib.pyplot as plt
import torch.nn as nn

from probability import *
from information import *

# %%
# %reload_ext autoreload

# %autoreload 2

# %%
net = CNN()
train_data = datasets.MNIST(
    root = 'data',
    train = True,
    transform = ToTensor(),
    download = True,
)

test_data = datasets.MNIST(
    root='data',
    train=False,
    transform=ToTensor()
)

mnist_train = torch.utils.data.DataLoader(train_data,
                                          batch_size=100,
                                          shuffle=True,
                                          num_workers=1)

mnist_test = torch.utils.data.DataLoader(test_data,
                                         batch_size=100,
                                         shuffle=True,
                                         num_workers=1)

total_step = len(mnist_train)

# %%
# рассмотрим первый батч

# %%
for i, (images, labels) in enumerate(mnist_train):
    output = net(images)[0]
    break

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
axs[0].imshow(images[0][0])
axs[1].imshow(images[10][0])
axs[2].imshow(images[14][0])

plt.show()

# %%
def discrete(x):
    return (x - 0.5 > 0) * 1.

# %%
avg_7 = nn.AvgPool2d(7)

fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
axs[0].imshow(discrete(avg_7(images)[0][0]))
axs[1].imshow(discrete(avg_7(images)[10][0]))
axs[2].imshow(discrete(avg_7(images)[14][0]))

plt.show()

# %%
max_7 = nn.MaxPool2d(7)

fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
axs[0].imshow(discrete(max_7(images)[0][0]))
axs[1].imshow(discrete(max_7(images)[10][0]))
axs[2].imshow(discrete(max_7(images)[14][0]))

plt.show()

# %%
max_4 = nn.MaxPool2d(4)

fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
axs[0].imshow(discrete(max_4(images)[0][0]))
axs[1].imshow(discrete(max_4(images)[10][0]))
axs[2].imshow(discrete(max_4(images)[14][0]))

plt.show()
